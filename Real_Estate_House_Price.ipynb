# %% [markdown]
# <a href="https://colab.research.google.com/github/Deb052024/Data-Visualization/blob/main/Real_Estate_House_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('/content/housing_data.csv')

# %%
df.info()
#Information About the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1460 non-null   int64
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   int64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.ndim
#Dimension of the Data Set
# Out:
# 2

# %%
# Identify numerical columns: columns with more than 5 unique values are considered numerical
numerical_columns = [col for col in df.columns if df[col].nunique() > 5]

# Identify categorical columns: columns that are not numerical and not 'GradeClass'
categorical_columns = df.columns.difference(numerical_columns).difference(['SalePrice']).to_list()

# %% [markdown]
# **Count Plot of the Categorical Variables of the Housing Data Set**

# %%
for column in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=column)
    plt.title(f'Countplot of {column}')

    # Directly set custom labels
    #labels = categorical_columns[column]
    #ticks = range(len(labels))
    #plt.xticks(ticks=ticks, labels=labels)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Histogram Plot of the Numerical Attributes of the Housing Data**

# %%
for column in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(data=df,x=column,kde=True)
    #sns.countplot(data=df, x=column)
    plt.title(f'Histplot of {column}')

    # Directly set custom labels
    #labels = categorical_columns[column]
    #ticks = range(len(labels))
    #plt.xticks(ticks=ticks, labels=labels)

    plt.tight_layout()
    plt.show()

# %%
df.describe()
#Summary of Data Set
# Out:
#         Unnamed: 0  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    729.500000    57.623288   10516.828082     6.099315     5.575342
# std     421.610009    34.664304    9981.264932     1.382997     1.112799
# min       0.000000     0.000000    1300.000000     1.000000     1.000000
# 25%     364.750000    42.000000    7553.500000     5.000000     5.000000
# 50%     729.500000    63.000000    9478.500000     6.000000     5.000000
# 75%    1094.250000    79.000000   11601.500000     7.000000     6.000000
# max    1459.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.117123   443.639726    46.549315  ...
# std      30.202904     20.645407   180.731373   456.098091   161.319273  ...
# ...

# %%
df.shape
#No Of Rows and Columns in Data Set
# Out:
# (1460, 81)

# %%
df.isnull().sum()
#Null Value check with the data set
# Out:
# Unnamed: 0       0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           0       SC60       RL           65     8450   Pave   NaN      Reg
# 1           1       SC20       RL           80     9600   Pave   NaN      Reg
# 2           2       SC60       RL           68    11250   Pave   NaN      IR1
# 3           3       SC70       RL           60     9550   Pave   NaN      IR1
# 4           4       SC60       RL           84    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 1         Lvl    AllPub  ...        0     No    No          No       0    May
# 2         Lvl    AllPub  ...        0     No    No          No       0    Sep
# 3         Lvl    AllPub  ...        0     No    No          No       0    Feb
# 4         Lvl    AllPub  ...        0     No    No          No       0    Dec
#
# ...

# %% [markdown]
# # MSSUBCLASS:Identifies the type of dwelling involved in the sale , Replacing the Attributes of MSSUBCLASS
#
# SC20=1-Story 1946&NEWER ALL STYLES
#
#
# SC70=2-STORY 1945 & OLDER
#
# SC60=2-STORY 1946  & NEWER

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC60':'2-STORY 1946 & NEWER','SC20':'1-STORY 1946 & NEWER ALL STYLES','SC70':'2-STORY 1945 & OLDER'})

# %%
df
# Out:
#       Unnamed: 0                       MSSubClass MSZoning  LotFrontage  \
# 0              0             2-STORY 1946 & NEWER       RL           65
# 1              1  1-STORY 1946 & NEWER ALL STYLES       RL           80
# 2              2             2-STORY 1946 & NEWER       RL           68
# 3              3             2-STORY 1945 & OLDER       RL           60
# 4              4             2-STORY 1946 & NEWER       RL           84
# ...          ...                              ...      ...          ...
# 1455        1455             2-STORY 1946 & NEWER       RL           62
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES       RL           85
# 1457        1457             2-STORY 1945 & OLDER       RL           66
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES       RL           68
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES       RL           75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %%
df['MSSubClass'].value_counts()
# Out:
# MSSubClass
# 1-STORY 1946 & NEWER ALL STYLES    536
# 2-STORY 1946 & NEWER               299
# SC50                               144
# SC120                               87
# SC30                                69
# SC160                               63
# 2-STORY 1945 & OLDER                60
# SC80                                58
# SC90                                52
# SC190                               30
# SC85                                20
# SC75                                16
# SC45                                12
# SC180                               10
# SC40                                 4
# Name: count, dtype: int64

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC50':'1-1/2 STORY FINISHED ALL AGES','SC30':'1-STORY 1945 & OLDER','SC120':'1-STORY PUD (Planned Unit Development) - 1946 & NEWER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC80':'SPLIT OR MULTI-LEVEL','SC90':'DUPLEX - ALL STYLES AND AGES','SC190':'2 FAMILY CONVERSION - ALL STYLES AND AGES'})

# %%
df['MSSubClass'].value_counts()
# Out:
# MSSubClass
# 1-STORY 1946 & NEWER ALL STYLES                          536
# 2-STORY 1946 & NEWER                                     299
# 1-1/2 STORY FINISHED ALL AGES                            144
# 1-STORY PUD (Planned Unit Development) - 1946 & NEWER     87
# 1-STORY 1945 & OLDER                                      69
# SC160                                                     63
# 2-STORY 1945 & OLDER                                      60
# SPLIT OR MULTI-LEVEL                                      58
# DUPLEX - ALL STYLES AND AGES                              52
# 2 FAMILY CONVERSION - ALL STYLES AND AGES                 30
# SC85                                                      20
# SC75                                                      16
# SC45                                                      12
# SC180                                                     10
# SC40                                                       4
# Name: count, dtype: int64

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC85':'SPLIT FOYER','SC75':'2-1/2 STORY ALL AGES','SC45':'1-1/2 STORY - UNFINISHED ALL AGES','SC180':'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER'})

# %%
df['MSSubClass']=df['MSSubClass'].replace({'SC40':'1-STORY W/FINISHED ATTIC ALL AGES'})

# %%
df['MSSubClass'].value_counts()
# Out:
# MSSubClass
# 1-STORY 1946 & NEWER ALL STYLES                          536
# 2-STORY 1946 & NEWER                                     299
# 1-1/2 STORY FINISHED ALL AGES                            144
# 1-STORY PUD (Planned Unit Development) - 1946 & NEWER     87
# 1-STORY 1945 & OLDER                                      69
# SC160                                                     63
# 2-STORY 1945 & OLDER                                      60
# SPLIT OR MULTI-LEVEL                                      58
# DUPLEX - ALL STYLES AND AGES                              52
# 2 FAMILY CONVERSION - ALL STYLES AND AGES                 30
# SPLIT FOYER                                               20
# 2-1/2 STORY ALL AGES                                      16
# 1-1/2 STORY - UNFINISHED ALL AGES                         12
# PUD - MULTILEVEL - INCL SPLIT LEV/FOYER                   10
# 1-STORY W/FINISHED ATTIC ALL AGES                          4
# Name: count, dtype: int64

# %% [markdown]
# **Renaming the Feature MSSubClass to Type Of Dwell**

# %%
df.rename(columns={'MSSubClass':'Type Of Dwell'},inplace=True)

# %%
df
# Out:
#       Unnamed: 0                    Type Of Dwell MSZoning  LotFrontage  \
# 0              0             2-STORY 1946 & NEWER       RL           65
# 1              1  1-STORY 1946 & NEWER ALL STYLES       RL           80
# 2              2             2-STORY 1946 & NEWER       RL           68
# 3              3             2-STORY 1945 & OLDER       RL           60
# 4              4             2-STORY 1946 & NEWER       RL           84
# ...          ...                              ...      ...          ...
# 1455        1455             2-STORY 1946 & NEWER       RL           62
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES       RL           85
# 1457        1457             2-STORY 1945 & OLDER       RL           66
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES       RL           68
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES       RL           75
#
#       LotArea Street Alley LotShape LandContour Utilities  ... PoolArea  \
# ...

# %%
df['Type Of Dwell'].value_counts()
# Out:
# Type Of Dwell
# 1-STORY 1946 & NEWER ALL STYLES                          536
# 2-STORY 1946 & NEWER                                     299
# 1-1/2 STORY FINISHED ALL AGES                            144
# 1-STORY PUD (Planned Unit Development) - 1946 & NEWER     87
# 1-STORY 1945 & OLDER                                      69
# SC160                                                     63
# 2-STORY 1945 & OLDER                                      60
# SPLIT OR MULTI-LEVEL                                      58
# DUPLEX - ALL STYLES AND AGES                              52
# 2 FAMILY CONVERSION - ALL STYLES AND AGES                 30
# SPLIT FOYER                                               20
# 2-1/2 STORY ALL AGES                                      16
# 1-1/2 STORY - UNFINISHED ALL AGES                         12
# PUD - MULTILEVEL - INCL SPLIT LEV/FOYER                   10
# 1-STORY W/FINISHED ATTIC ALL AGES                          4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(60,35))
#sns.boxplot(data=df,x=df['Type Of Dwell'],y=df['SalePrice'])
sns.countplot(data=df,x=df['Type Of Dwell'])
# Out:
# <Axes: xlabel='Type Of Dwell', ylabel='count'>

# %% [markdown]
# **Value Count of Type of Dwell**

# %%
df['Type Of Dwell'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Type Of Dwell'>

# %%
df['MSZoning'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='MSZoning'>

# %% [markdown]
# # **Replacing the Parameters of MSZoning **

# %%
df['MSZoning']=df['MSZoning'].replace({'RL':'Residential Low-Density','RH':'Residential High-Density','RP':'Residential Low-Density Park','RM':'Residential Medium Density'})

# %% [markdown]
# **Renaming Mszoing to General Zoning**

# %%
df.rename(columns={'MSZoning':'GeneralZoning'},inplace=True)

# %%
df['GeneralZoning']=df['GeneralZoning'].replace({'FV':'Floating Village Residential','C (all)':'Commercial'})

# %%
df['GeneralZoning'].value_counts()
# Out:
# GeneralZoning
# RL                              1151
# RM                               218
# Floating Village Residential      65
# RH                                16
# Commercial                        10
# Name: count, dtype: int64

# %%
df['GeneralZoning'].unique()
# Out:
# array(['RL', 'RM', 'Commercial', 'Floating Village Residential', 'RH'],
#       dtype=object)

# %% [markdown]
# **LotFrontage to be renamed as Linear Feet of Street**

# %%
df.rename(columns={'LotFrontage':'Linear Feet of Street'},inplace=True)

# %%
df
# Out:
#       Unnamed: 0                    Type Of Dwell GeneralZoning  \
# 0              0             2-STORY 1946 & NEWER            RL
# 1              1  1-STORY 1946 & NEWER ALL STYLES            RL
# 2              2             2-STORY 1946 & NEWER            RL
# 3              3             2-STORY 1945 & OLDER            RL
# 4              4             2-STORY 1946 & NEWER            RL
# ...          ...                              ...           ...
# 1455        1455             2-STORY 1946 & NEWER            RL
# 1456        1456  1-STORY 1946 & NEWER ALL STYLES            RL
# 1457        1457             2-STORY 1945 & OLDER            RL
# 1458        1458  1-STORY 1946 & NEWER ALL STYLES            RL
# 1459        1459  1-STORY 1946 & NEWER ALL STYLES            RL
#
#       Linear Feet of Street  LotArea Street Alley LotShape LandContour  \
# 0                        65     8450   Pave   NaN      Reg         Lvl
# ...

# %% [markdown]
# **Lot Area to be Renamed as Lot Size in Square Feet**

# %%
df.rename({'LotArea':'Lot Size in Square Feet'},inplace=True)

# %%
df['Street'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Street'>

# %% [markdown]
# **Street to be Renamed as Type of Road**

# %%
df.rename(columns={'Street':'Type of Road'},inplace=True)

# %% [markdown]
# **Type of Alley Access to the Property**

# %%
df['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %% [markdown]
# **Features of Alley were Replaced**

# %%
df['Alley']=df['Alley'].replace({'Grvl':'Gravel','Pave':'Paved'})

# %% [markdown]
# **General Shape of The Property**

# %%
df['LotShape'].value_counts()
# Out:
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64

# %% [markdown]
# **The attributes of Shape of the Property were Modified**

# %%
df['LotShape']=df['LotShape'].replace({'IR1':'Slightly irregular','IR2':'Moderately Irregular','IR3':'Irregular','Reg':'Regular'})

# %% [markdown]
# **LotShape of the Property was Renamed to General Shape of Property**

# %%
df.rename(columns={'LotShape':'General Shape of Property'},inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street',
#        'LotArea', 'Type of Road', 'Alley', 'General Shape of Property',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
# ...

# %%
df['General Shape of Property'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='General Shape of Property'>

# %% [markdown]
# **Rename from** **LandContour** to **Flatness of the Property**

# %%
df.rename(columns={'LandContour':'Flatness of the property'},inplace=True)

# %% [markdown]
# **Replacing the Features of Flatness of the Property**

# %%
df['Flatness of the property']=df['Flatness of the property'].replace({'Lvl':'Near Flat','Bnk':'Banked','HLS':'Hillside'})

# %%
df['Flatness of the property'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Flatness of the property'>

# %% [markdown]
# **Rename of Utilities to Type of Utilities in the Property**
#
#   AllPub        All public Utilities (E,G,W,& S)
#
#    NoSewr    	Electricity, Gas, and Water (Septic Tank)
#
#    NoSeWa   	Electricity and Gas Only
#
#    ELO          	Electricity only

# %%
df.rename(columns={'Utilities':'Type of Utilities'},inplace=True)

# %%
df['Type of Utilities']=df['Type of Utilities'].replace({'AllPub':'All Public Facilities','NoSeWa':'Electricity and Gas Only'})

# %%
df['Type of Utilities'].value_counts()
# Out:
# Type of Utilities
# All Public Facilities       1459
# Electricity and Gas Only       1
# Name: count, dtype: int64

# %% [markdown]
# **Rename of Lot Configuration** and **Replace of the attributes**

# %%
df.rename(columns={'LotConfig':'Lot configuration'},inplace=True)

# %%
df['Lot configuration'].value_counts()
# Out:
# Lot configuration
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64

# %%
df['Lot configuration']=df['Lot configuration'].replace({'FR2':'Frontage on 2 sides of the property','FR3':'Frontage on 3 sides of the Property','CulDSac':'Cul-de-sac'})

# %%
df['Lot configuration'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Lot configuration'>

# %% [markdown]
# **Rename and Replacing the attributes of LandSlope**

# %%
df.rename(columns={'LandSlope':'Slope of Property'},inplace=True)

# %%
df['Slope of Property'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Slope of Property'>

# %% [markdown]
# **Replacement of few  attributes of Neighborhood Attribute**
#
#    Blmngtn                    	Bloomington Heights
#
#    Blueste        	Bluestem
#
#    BrDale         	Briardale
#
#    BrkSide        	Brookside
#
#    ClearCr        	Clear Creek
#
#    CollgCr       	College Creek
#
#    Crawfor      	Crawford
#
#    Edwards      	Edwards
#
#    Gilbert        	Gilbert
#
#    IDOTRR     	Iowa DOT and Rail Road
#
#    MeadowV    	Meadow Village
#
#    Mitchel        	Mitchell
#
#    Names        	North Ames
#
#
#    NoRidge      	Northridge
#
#    NPkVill      	Northpark Villa
#
#    NridgHt      	Northridge Heights
#
#    NWAmes       	Northwest Ames
#
#    OldTown      	Old Town
#
#    SWISU        	South & West of Iowa State University
#
#    Sawyer         	Sawyer
#
#    SawyerW      	Sawyer West
#
#    Somerst       	Somerset
#
#    StoneBr        	Stone Brook
#
#    Timber         	Timberland
#
#    Veenker    	   Veenker

# %%
df['Neighborhood']=df['Neighborhood'].replace({'Veenker':'Veenker','Timber':'Timberland','StoneBr':'Stone Brook','Somerst':'Somerset','OldTown':'Old Town','Sawyer':'Sawyer','SWISU':'South & West of Iowa University','OldTown':'Old Town','NWAmes':'Northwest Ames','NriddgHt':'Northridge Heights','NPkVilla':'Northpark Villa','NoRidge':'Northridge','Names':'North Ames'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'CollgCr':'College Creek','ClearCr':'Clear Creek','BrkSide':'Brookside','BrDale':'Briardale','Blueste':'Bluestem','Blmngtn':'Bloomington Heights'})

# %%
df['Neighborhood']=df['Neighborhood'].replace({'IDOTRR':'Iowa DOT and Rail Road',' NPkVill':'Northpark Villa','NridgHt':'Northridge Heights'})

# %%
df['Neighborhood'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Neighborhood'>

# %%
df.iloc[0:12,12:]
# Out:
#           Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  \
# 0        College Creek       Norm       Norm     1Fam     2Story            7
# 1              Veenker      Feedr       Norm     1Fam     1Story            6
# 2        College Creek       Norm       Norm     1Fam     2Story            7
# 3              Crawfor       Norm       Norm     1Fam     2Story            7
# 4           Northridge       Norm       Norm     1Fam     2Story            8
# 5              Mitchel       Norm       Norm     1Fam     1.5Fin            5
# 6             Somerset       Norm       Norm     1Fam     1Story            8
# 7       Northwest Ames       PosN       Norm     1Fam     2Story            7
# 8             Old Town     Artery       Norm     1Fam     1.5Fin            7
# 9            Brookside     Artery     Artery   2fmCon     1.5Unf            5
# 10              Sawyer       Norm       Norm     1Fam     1Story            5
# ...

# %% [markdown]
# **Acess to Specific Rows and Columns on the Data Frame**

# %%
df.iloc[0:5,10:20]
# Out:
#                      Lot configuration Slope of Property   Neighborhood  \
# 0                               Inside               Gtl  College Creek
# 1  Frontage on 2 sides of the property               Gtl        Veenker
# 2                               Inside               Gtl  College Creek
# 3                               Corner               Gtl        Crawfor
# 4  Frontage on 2 sides of the property               Gtl     Northridge
#
#   Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0       Norm       Norm     1Fam     2Story            7            5
# 1      Feedr       Norm     1Fam     1Story            6            8
# 2       Norm       Norm     1Fam     2Story            7            5
# 3       Norm       Norm     1Fam     2Story            7            5
# 4       Norm       Norm     1Fam     2Story            8            5
#
#    YearBuilt
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000

# %% [markdown]
# **Rename and Reshape of the Feature Condition 1 and Condition 2**
#
# Condition1: Proximity to various conditions
#
#   Artery         	Adjacent to arterial street
#
#    Feedr        	Adjacent to feeder street
#
#    Norm        	Normal
#
#    RRNn       	Within 200' of North-South Railroad
#
#    RRAn        	Adjacent to North-South Railroad
#
#    PosN        	Near positive off-site feature--park, greenbelt, etc.
#
#    PosA         	Adjacent to positive off-site feature
#
#    RRNe       	Within 200' of East-West Railroad
#
#    RRAe        	Adjacent to East-West Railroad
#
#    Condition 2: Proximity to various conditions (if more than one is present)
#
#   Artery         	Adjacent to arterial street
#
#    Feedr        	Adjacent to feeder street
#
#    Norm        	Normal
#
#    RRNn       	Within 200' of North-South Railroad
#
#    RRAn        	Adjacent to North-South Railroad
#
#    PosN        	Near positive off-site feature--park, greenbelt, etc.
#
#    PosA         	Adjacent to positive off-site feature
#
#    RRNe       	Within 200' of East-West Railroad
#
#    RRAe        	Adjacent to East-West Railroad

# %%
df['Condition1']=df['Condition1'].replace({'Artery':'Adjacent to arterial street','Feedr':'Adjacent to feeder street','Norm':'Normal','RRNn':'Within 200 of North-South Railroad'})

# %%
df['Condition1']=df['Condition1'].replace({'RRAn':'Adjacent to North-South Railroad','PosN':'Near positive off-site feature--park, greenbelt, etc','PosA':'Adjacent to positive off-site feature','RRNe':'Within 200 of East-West Railroad','RRAe':'Adjacent to East-West Railroad'})

# %%
df['Condition2']=df['Condition2'].replace({'Artery':'Adjacent to arterial street','Feedr':'Adjacent to feeder street','Norm':'Normal','RRNn':'Within 200 of North-South Railroad'})

# %%
df['Condition2']=df['Condition2'].replace({'RRAn':'Adjacent to North-South Railroad','PosN':'Near positive off-site feature--park, greenbelt, etc','PosA':'Adjacent to positive off-site feature','RRNe':'Within 200 of East-West Railroad','RRAe':'Adjacent to East-West Railroad'})

# %%
df['Condition1'].value_counts()
# Out:
# Condition1
# Normal                                                  1260
# Adjacent to feeder street                                 81
# Adjacent to arterial street                               48
# Adjacent to North-South Railroad                          26
# Near positive off-site feature--park, greenbelt, etc      19
# Adjacent to East-West Railroad                            11
# Adjacent to positive off-site feature                      8
# Within 200 of North-South Railroad                         5
# Within 200 of East-West Railroad                           2
# Name: count, dtype: int64

# %% [markdown]
# **Make Feature enginerring Function To make One column from two columns**

# %%
def column_addition(x,y):
  if x!=y:
    return (x+' &' +y)
  else:
      return x

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street',
#        'LotArea', 'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **"Feature Engineering" : Addition of Two columns to One**

# %%
df['Condition1']=df.apply(lambda a:column_addition(a['Condition1'],a['Condition2']),axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0                    Type Of Dwell            GeneralZoning  \
# 0           0             2-STORY 1946 & NEWER  Residential Low-Density
# 1           1  1-STORY 1946 & NEWER ALL STYLES  Residential Low-Density
# 2           2             2-STORY 1946 & NEWER  Residential Low-Density
# 3           3             2-STORY 1945 & OLDER  Residential Low-Density
# 4           4             2-STORY 1946 & NEWER  Residential Low-Density
#
#    Linear Feet of Street  LotArea Type of Road Alley LotShape LandContour  \
# 0                     65     8450        Paved   NaN      Reg         Lvl
# 1                     80     9600        Paved   NaN      Reg         Lvl
# 2                     68    11250        Paved   NaN      IR1         Lvl
# 3                     60     9550        Paved   NaN      IR1         Lvl
# 4                     84    14260        Paved   NaN      IR1         Lvl
#
#   Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# ...

# %%
df.iloc[0:5,12:18]
# Out:
#     Neighborhood                         Condition1 Condition2 BldgType  \
# 0  College Creek                             Normal     Normal     1Fam
# 1        Veenker  Adjacent to feeder street &Normal     Normal     1Fam
# 2  College Creek                             Normal     Normal     1Fam
# 3        Crawfor                             Normal     Normal     1Fam
# 4     Northridge                             Normal     Normal     1Fam
#
#   HouseStyle  OverallQual
# 0     2Story            7
# 1     1Story            6
# 2     2Story            7
# 3     2Story            7
# 4     2Story            8

# %%
df['Condition1'].value_counts()
# Out:
# Condition1
# Normal                                                                1260
# Adjacent to feeder street &Normal                                       76
# Adjacent to arterial street &Normal                                     45
# Adjacent to North-South Railroad &Normal                                22
# Near positive off-site feature--park, greenbelt, etc &Normal            17
# Adjacent to East-West Railroad &Normal                                  11
# Adjacent to positive off-site feature &Normal                            8
# Within 200 of North-South Railroad &Normal                               4
# Adjacent to North-South Railroad &Adjacent to feeder street              4
# Adjacent to feeder street &Within 200 of North-South Railroad            2
# Adjacent to arterial street                                              2
# Within 200 of East-West Railroad &Normal                                 2
# ...

# %% [markdown]
# **Dropping Condition 2 and Unnamed Column as not required for analysis**

# %%
df.drop(['Condition2','Unnamed: 0'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street', 'LotArea',
#        'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Condition1', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %% [markdown]
# **Renaming the Condition1 to Proximity to various condtions**

# %%
df.rename(columns={'Condition1':'Proximity to various conditions'},inplace=True)

# %%
df.columns
# Out:
# Index(['Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street', 'LotArea',
#        'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Proximity to various conditions',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df.iloc[0:5,12:]
# Out:
#      Proximity to various conditions BldgType HouseStyle  OverallQual  \
# 0                             Normal     1Fam     2Story            7
# 1  Adjacent to feeder street &Normal     1Fam     1Story            6
# 2                             Normal     1Fam     2Story            7
# 3                             Normal     1Fam     2Story            7
# 4                             Normal     1Fam     2Story            8
#
#    OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st  ...  \
# 0            5       2003          2003     Gable  CompShg     VinylSd  ...
# 1            8       1976          1976     Gable  CompShg     MetalSd  ...
# 2            5       2001          2002     Gable  CompShg     VinylSd  ...
# 3            5       1915          1970     Gable  CompShg     Wd Sdng  ...
# 4            5       2000          2000     Gable  CompShg     VinylSd  ...
#
#   PoolArea PoolQC  Fence MiscFeature MiscVal MoSold YrSold SaleType  \
# ...

# %%
df['Proximity to various conditions'].unique()
#Finding unique features on Proximity to various conditions
# Out:
# array(['Normal', 'Adjacent to feeder street &Normal',
#        'Near positive off-site feature--park, greenbelt, etc &Normal',
#        'Adjacent to arterial street &Normal',
#        'Adjacent to arterial street',
#        'Adjacent to East-West Railroad &Normal',
#        'Adjacent to feeder street &Within 200 of North-South Railroad',
#        'Within 200 of North-South Railroad &Normal',
#        'Adjacent to North-South Railroad &Adjacent to feeder street',
#        'Adjacent to positive off-site feature &Normal',
#        'Adjacent to feeder street',
#        'Adjacent to North-South Railroad &Normal',
#        'Within 200 of East-West Railroad &Normal',
#        'Near positive off-site feature--park, greenbelt, etc',
#        'Within 200 of North-South Railroad &Adjacent to feeder street',
#        'Adjacent to arterial street &Adjacent to positive off-site feature',
#        'Adjacent to feeder street &Adjacent to North-South Railroad',
# ...

# %%
df['Proximity to various conditions'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Proximity to various conditions'>

# %% [markdown]
# **BldgType to Dwelling Type**

# %%
df['BldgType'].value_counts()
# Out:
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64

# %%
df['BldgType']=df['BldgType'].replace({'1fam':'Single Family','TwnhsE':'Town House End Unit','Twnhs':'Town House','2fmCon':'Two-Family conversion'})

# %%
df.rename(columns={'BldgType':'Dewlling Type'},inplace=True)

# %%
df.columns
# Out:
# Index(['Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street', 'LotArea',
#        'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Proximity to various conditions',
#        'Dewlling Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
# ...

# %% [markdown]
# **Rename and Replacement of attributes of HouseStyle**

# %%
df['HouseStyle']=df['HouseStyle'].replace({'1.5Fin':'One and one-half story:2nd level finished','1.5Unf':'One and one-half story: 2nd level unfinished','2.5Fin':'Two and one-half story: 2nd level finished','2.5Unf':'Two and one-half story: 2nd level unfinished',' SFoyer':'Split Foyer'})

# %%
df.rename(columns={'HouseStyle':'Style of Dwelling'},inplace=True)

# %%
df['Style of Dwelling']=df['Style of Dwelling'].replace({'SLvl':'Split Level','SFoyer':'Split Foyer'})

# %%
df['Style of Dwelling'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Style of Dwelling'>

# %% [markdown]
# **Renaming the Features and the columns of OverallQual and OverallCond**

# %%
df['OverallQual']=df['OverallQual'].replace({10:'Very Excellent',9:'Excellent',8:'Very Good',7:'Good',6:'Above Average',5:'Average'})

# %%
df['OverallQual']=df['OverallQual'].replace({4:'Below Average',3:'Fair',2:'Poor',1:'Very Poor'})

# %%
df['OverallQual'].value_counts()
# Out:
# OverallQual
# Average           397
# Above Average     374
# Good              319
# Very Good         168
# Below Average     116
# Excellent          43
# Fair               20
# Very Excellent     18
# Poor                3
# Very Poor           2
# Name: count, dtype: int64

# %%
df['OverallCond']=df['OverallCond'].replace({10:'Very Excellent',9:'Excellent',8:'Very Good',7:'Good',6:'Above Average',5:'Average'})

# %%
df['OverallCond']=df['OverallCond'].replace({4:'Below Average',3:'Fair',2:'Poor',1:'Very Poor'})

# %%
df['OverallQual'].value_counts()
# Out:
# OverallQual
# Average           397
# Above Average     374
# Good              319
# Very Good         168
# Below Average     116
# Excellent          43
# Fair               20
# Very Excellent     18
# Poor                3
# Very Poor           2
# Name: count, dtype: int64

# %%
df['OverallCond'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OverallCond'>

# %%
df['OverallQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OverallQual'>

# %% [markdown]
# **YearBuilt modified to Original Construction Date**

# %%
df.rename(columns={'YearBuilt':'Original Constrction Date'},inplace=True)

# %%
df['Original Constrction Date'].unique()
# Out:
# array([2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939, 1965,
#        2005, 1962, 2006, 1960, 1929, 1970, 1967, 1958, 1930, 2002, 1968,
#        2007, 1951, 1957, 1927, 1920, 1966, 1959, 1994, 1954, 1953, 1955,
#        1983, 1975, 1997, 1934, 1963, 1981, 1964, 1999, 1972, 1921, 1945,
#        1982, 1998, 1956, 1948, 1910, 1995, 1991, 2009, 1950, 1961, 1977,
#        1985, 1979, 1885, 1919, 1990, 1969, 1935, 1988, 1971, 1952, 1936,
#        1923, 1924, 1984, 1926, 1940, 1941, 1987, 1986, 2008, 1908, 1892,
#        1916, 1932, 1918, 1912, 1947, 1925, 1900, 1980, 1989, 1992, 1949,
#        1880, 1928, 1978, 1922, 1996, 2010, 1946, 1913, 1937, 1942, 1938,
#        1974, 1893, 1914, 1906, 1890, 1898, 1904, 1882, 1875, 1911, 1917,
#        1872, 1905])

# %%
df.rename(columns={'YearRemodAdd':'Remodel Date'},inplace=True)

# %%
df['Original Constrction Date'].isnull().sum()
# Out:
# 0

# %%
df['Remodel Date'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Make Function to fill Zero values in Remodel Date of Property Column**

# %%
def fill_zero_value(x,y):
  if y==0:
    return x
  else:
    return y

# %%
df['Remodel Date']=df.apply(lambda a:fill_zero_value(a['Original Constrction Date'],a['Remodel Date']),axis=1)

# %%
df.iloc[2:5,10:20]
# Out:
#   Slope of Property   Neighborhood Proximity to various conditions  \
# 2               Gtl  College Creek                          Normal
# 3               Gtl        Crawfor                          Normal
# 4               Gtl     Northridge                          Normal
#
#   Dewlling Type Style of Dwelling OverallQual OverallCond  \
# 2          1Fam            2Story        Good     Average
# 3          1Fam            2Story        Good     Average
# 4          1Fam            2Story   Very Good     Average
#
#    Original Constrction Date  Remodel Date RoofStyle
# 2                       2001          2002     Gable
# 3                       1915          1970     Gable
# 4                       2000          2000     Gable

# %% [markdown]
# **Roof Material Renaming and attribute Changes**

# %%
df.rename(columns={'RoofMatl':'RoofMaterial'},inplace=True)

# %%
df['RoofMaterial']=df['RoofMaterial'].replace({'ClyTile':'Clay or Tile','CompShg':'Standard (Composite) Shingle','Membran':'Membrane','Tar&Grv':'Gravel & Tar','WdShake':'Wood Shakes','WdShngl':'Wood Shingles'})

# %%
df['RoofMaterial'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='RoofMaterial'>

# %% [markdown]
# **Rename and Replace Attributes of Exterior 1st**

# %%
df['Exterior1st']=df['Exterior1st'].replace({'AsbShng':'Asbestos Shingles','AsphShn':'Asphalt Shingles','BrkComm':'Brick Common','BrkFace':'Brick Face','CBlock':'Cinder Block','CemntBd':'Cement Board'})

# %%
df['Exterior1st']=df['Exterior1st'].replace({'HdBoard':'Hard Board','ImStucc':'Imitation Stucco','MetalSd':'Metal Siding',' VinylSd':'Vinyl Siding','Wd Sdng':'Wood Siding','WdShing':'Wood Shingles'})

# %%
df['Exterior1st'].value_counts()
# Out:
# Exterior1st
# VinylSd              515
# Hard Board           222
# Metal Siding         220
# Wood Siding          206
# Plywood              108
# Cement Board          61
# Brick Face            50
# Wood Shingles         26
# Stucco                25
# Asbestos Shingles     20
# Brick Common           2
# Stone                  2
# Asphalt Shingles       1
# Imitation Stucco       1
# Cinder Block           1
# Name: count, dtype: int64

# %% [markdown]
# **Rename and Replace Attributes of Exterior 2nd**

# %%
df['Exterior2nd']=df['Exterior2nd'].replace({'AsbShng':'Asbestos Shingles','AsphShn':'Asphalt Shingles','BrkComm':'Brick Common','BrkFace':'Brick Face','CBlock':'CinderBlock','CemntBd':'CementBoard','HdBoard':'HardBoard','ImStucc':'ImitationStucco','MetalSd':'Metal Siding','VinylSd':'Vinyl Siding'})

# %%
df['Exterior2nd']=df['Exterior2nd'].replace({'Wd Sdng':'Wood Siding','WdShing':'Wood Shingles'})

# %% [markdown]
# **Add Exterior 1 and 2 column and make them one Column**

# %%
df['Exterior1st']=df.apply(lambda a:column_addition(a['Exterior1st'],a['Exterior2nd']),axis=1)

# %%
df.rename(columns={'Exterior1st':'Exterior Covering on House'},inplace=True)

# %%
df.columns
# Out:
# Index(['Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street', 'LotArea',
#        'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Proximity to various conditions',
#        'Dewlling Type', 'Style of Dwelling', 'OverallQual', 'OverallCond',
#        'Original Constrction Date', 'Remodel Date', 'RoofStyle',
#        'RoofMaterial', 'Exterior Covering on House', 'Exterior2nd',
#        'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
# ...

# %% [markdown]
# **Drop Exterior 2 Column as its not Required**

# %%
df.drop('Exterior2nd',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Type Of Dwell', 'GeneralZoning', 'Linear Feet of Street', 'LotArea',
#        'Type of Road', 'Alley', 'General Shape of Property',
#        'Flatness of the property', 'Type of Utilities', 'Lot configuration',
#        'Slope of Property', 'Neighborhood', 'Proximity to various conditions',
#        'Dewlling Type', 'Style of Dwelling', 'OverallQual', 'OverallCond',
#        'Original Constrction Date', 'Remodel Date', 'RoofStyle',
#        'RoofMaterial', 'Exterior Covering on House', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
# ...

# %% [markdown]
# **Filling Null Values with Mode for Masonry Veeneer Type and replacing the attrobutes**

# %% [markdown]
# **Unique Values of The Street Column**

# %%
df['Street'].unique()
# Out:
# array(['Paved', 'Garvel'], dtype=object)

# %%
df['MSSubclass'].iloc[0:10,50:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MSSubclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# MSSubClass       object
# MSZoning         object
# LotFrontage       int64
# LotArea           int64
#                   ...
# MoSold           object
# YrSold            int64
# SaleType         object
# SaleCondition    object
# SalePrice         int64
# Length: 81, dtype: object

# %%
df.duplicated().sum()
#Duplicate Value check in Data Set
# Out:
# 0

# %%
df.columns
#Columns in the Data Set
# Out:
# Index(['Unnamed: 0', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
df['sqftPrice']=df['SalePrice']/df['LotArea']
#Feature Engineering

# %%
plt.bar(data=df,y=df['sqftPrice'],x=df['LotArea'],color ='maroon',width = 0.4)
plt.xlbabel('LotArea')
plt.ylabel('sqftPrice')
plt.show()
plt.title("Students enrolled in different courses")
plt.figsize(figure=(16,20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-4deac322c014> in <cell line: 1>()
# ----> 1 plt.bar(data=df,y=df['sqftPrice'],x=df['LotArea'],color ='maroon',width = 0.4)
#       2 plt.xlbabel('LotArea')
#       3 plt.ylabel('sqftPrice')
#       4 plt.show()
#       5 plt.title("Students enrolled in different courses")
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df.dtypes[['SalePrice','sqftPrice']]
# Out:
# SalePrice      int64
# sqftPrice    float64
# dtype: object

# %%
plt.figure(figsize=(5,5))
sns.boxplot(df['sqftPrice'])
# Out:
# <Axes: ylabel='sqftPrice'>

# %%
pd.crosstab(df['sqftPrice'],df['LotArea'])
# Out:
# LotArea    1300    1477    1491    1526    1533    1596    1680    1869    \
# sqftPrice
# 1.390441        0       0       0       0       0       0       0       0
# 1.742138        0       0       0       0       0       0       0       0
# 1.742201        0       0       0       0       0       0       0       0
# 2.504422        0       0       0       0       0       0       0       0
# 2.622689        0       0       0       0       0       0       0       0
# ...           ...     ...     ...     ...     ...     ...     ...     ...
# 78.684211       0       0       0       0       0       0       0       0
# 79.593765       0       0       0       0       0       0       0       0
# 83.608880       0       0       0       0       0       0       0       0
# 83.845064       0       0       0       0       0       0       0       0
# 95.384615       1       0       0       0       0       0       0       0
#
# ...

# %%
df.iloc[10:20]
# Out:
#     Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 10          10       SC20       RL           70    11200   Pave   NaN
# 11          11       SC60       RL           85    11924   Pave   NaN
# 12          12       SC20       RL            0    12968   Pave   NaN
# 13          13       SC20       RL           91    10652   Pave   NaN
# 14          14       SC20       RL            0    10920   Pave   NaN
# 15          15       SC45       RM           51     6120   Pave   NaN
# 16          16       SC20       RL            0    11241   Pave   NaN
# 17          17       SC90       RL           72    10791   Pave   NaN
# 18          18       SC20       RL           66    13695   Pave   NaN
# 19          19       SC20       RL           70     7560   Pave   NaN
#
#    LotShape LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal  \
# 10      Reg         Lvl    AllPub  ...     No     No          No       0
# ...

# %%
df.iloc[10:20,0:10]
# Out:
#     Unnamed: 0 MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# 10          10       SC20       RL           70    11200   Pave   NaN
# 11          11       SC60       RL           85    11924   Pave   NaN
# 12          12       SC20       RL            0    12968   Pave   NaN
# 13          13       SC20       RL           91    10652   Pave   NaN
# 14          14       SC20       RL            0    10920   Pave   NaN
# 15          15       SC45       RM           51     6120   Pave   NaN
# 16          16       SC20       RL            0    11241   Pave   NaN
# 17          17       SC90       RL           72    10791   Pave   NaN
# 18          18       SC20       RL           66    13695   Pave   NaN
# 19          19       SC20       RL           70     7560   Pave   NaN
#
#    LotShape LandContour Utilities
# 10      Reg         Lvl    AllPub
# 11      IR1         Lvl    AllPub
# 12      IR2         Lvl    AllPub
# 13      IR1         Lvl    AllPub
# ...

# %%
df.iloc[10:20,20:35]
# Out:
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 10          1965       Hip  CompShg     HdBoard     HdBoard        NaN
# 11          2006       Hip  CompShg     WdShing     Wd Shng      Stone
# 12          1962       Hip  CompShg     HdBoard     Plywood        NaN
# 13          2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 14          1960       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 15          2001     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
# 16          1970     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 17          1967     Gable  CompShg     MetalSd     MetalSd        NaN
# 18          2004     Gable  CompShg     VinylSd     VinylSd        NaN
# 19          1965       Hip  CompShg     BrkFace     Plywood        NaN
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 10           0        TA        TA     CBlock       TA       TA           No
# ...

# %%
onehotencoder=pd.get_dummies(df,columns=[])

# %%
#Plots , barplot,histogram
